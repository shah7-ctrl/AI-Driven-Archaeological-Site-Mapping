# %%
# Core libraries
# !pip install numpy pandas matplotlib seaborn opencv-python scikit-learn

# Geospatial & mapping
# !pip install rasterio geopandas folium shapely

# Dashboard (choose one)
# !pip install dash

# Image augmentation
# !pip install albumentations

# Deep learning (PyTorch version, widely used with albumentations + YOLO)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu

# Optional: for YOLO
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 60.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 54.4 MB/s eta 0:00:00
# ...
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 19.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# 'Colab Notebooks'		      'vegetation segmentation.v2i.yolov8.zip'
# 'vegetation segmentation.v2i.yolov8'

# %%
# !ls "/content/drive/MyDrive/vegetation segmentation.v2i.yolov8"
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid
